# %% [markdown]
# # 과제: 네이버 영화 정보 및 평점 크롤링

# %% [markdown]
# - 대상: 예매순 상위 5개의 현재 상영 중인 영화
# - 수집할 항목: 영화 제목, 주연배우 3인, 네티즌 평점, 관람객 평점, 기자/평론가 평점, 관람객 별점 리뷰 20건 공감순으로(평점, 작성자닉네임, 리뷰본문)

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
data = dict()

# %% [markdown]
# ### 1. 예매순 상위 5개의 현재 상영 중인 영화 가져오기

# %% [markdown]
# 영화 제목, 주연배우 3인

# %%
def movie_title_url_actor(top_num, major_actor_num, dic):
    '''
        top_num: 예매순 상위 top_num개
        major_actor_num: 주연배우 major_actor_num 명
        dic: 딕셔너리
    '''
    url = 'https://movie.naver.com/movie/running/current.nhn'
    res = requests.get(url, headers={'User-Agent':'Mozilla/5.0'})
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.find_all(class_ ='tit')
    for title in titles[0:top_num]:
        dic[title.find('a').text] = dict()
        dic[title.find('a').text]['url'] = title.find('a').get('href')
    
    idx= 0
    infos = soup.find_all(class_ ='info_txt1')
    for info in infos[0:top_num]:
        actors_list = info.select_one("dd:nth-of-type(3)").text.strip().split(',')
        actors = []
        n = 1
        for actor in actors_list:
            if n==(major_actor_num+1):
                break
            actors.append(actor.strip())
            n+=1
        dic[list(dic.keys())[idx]]['actors'] = actors
        idx+=1
        
    return dic

# %% [markdown]
# ### 2. 해당 영화의 평점 가져오기

# %% [markdown]
# 네티즌 평점, 관람객 평점, 기자/평론가 평점

# %%
def get_grade(url):
    '''
        url: 위의 함수에서 저장한 url
    '''
    full_url = 'https://movie.naver.com'+url
    res = requests.get(full_url, headers={'User-Agent':'Mozilla/5.0'})
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    
    p = re.compile('[0-9]{2}.[0-9]{1}') #평점 가져오는 방법들 중 하나 (별점 style의 width로 계산)
    likey = soup.find_all(class_ ='st_on')
    
    # [관람객, 평론가, 네티즌]
    grades = []
    for like in likey[0:3]:
        grades.append(float(p.findall(like.get('style'))[0])*0.1)
        
    return grades

# %%
def insert_grades(dic):
    for movie in dic:
        grades = get_grade(data[movie]['url'])
        data[movie]['관람객평점'] = grades[0]
        data[movie]['평론가평점'] = grades[1]
        data[movie]['네티즌평점'] = grades[2]
    return dic

# %% [markdown]
# ### 3. 관람객 평점 공감순 20건 가져오기

# %% [markdown]
# 평점, 평점 작성자 닉네임, 리뷰 본문

# %%
def get_code(url):
    p = re.compile('[0-9]{6}')
    return p.findall(url)[0]

# %%
def get_reviews(url, page):
    '''
        url: 영화 url
        page: 수집하고자 하는 데이터 수 / 10
    '''
    code = get_code(url)
    reviews = []
    
    for p in range(1, page+1):
        url = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code={code}&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={page}'.format(code=code, page=p)
        res = requests.get(url, headers={'User-Agent':'Mozilla/5.0'})
        html = res.text
        soup = BeautifulSoup(html, 'html.parser')
        score_result = soup.find('div', {'class': 'score_result'})
        
        # 리스트
        lis = score_result.findAll('li')
        length = len(lis)
        
        for idx in range(length):
            dic = dict()
    
            # 평점
            try:
                dic['평점'] = lis[idx].find('em').text
            except:
                pass

            # 평점 작성자 닉네임 (괄호 제거 시 가산점)
            try:
                dic['닉네임'] = lis[idx].findAll('a')[0].find('span').text
            except:
                pass
            
            # 리뷰 본문
            try:
                dic['리뷰 본문'] = lis[idx].find('p').text[4:].strip()
            except:
                pass
            
            reviews.append(dic)

    return reviews

# %%
def insert_reviews(dic, data_num):
    '''
        data_num: 수집하려는 데이터 개수
    '''
    page = data_num//10
    for movie in dic:
        reviews = get_reviews(data[movie]['url'], page)
        data[movie]['리뷰'] = reviews
    return dic

# %% [markdown]
# ### 4. 저장하기

# %%
import json

# %%
def dic_to_json(dic, filename):
    with open('./{}.json'.format(filename),'w', encoding='utf-8') as fp:
        json.dump(dic, fp, indent=4, ensure_ascii=False)

# %% [markdown]
# ### 5. 크롤링하기

# %%
data = movie_title_url_actor(5, 3, data)

# %%
data
# Out:
# {'정직한 후보': {'url': '/movie/bi/mi/basic.nhn?code=186821',
#   'actors': ['라미란', '김무열', '나문희']},
#  '작은 아씨들': {'url': '/movie/bi/mi/basic.nhn?code=186613',
#   'actors': ['시얼샤 로넌', '엠마 왓슨', '플로렌스 퓨']},
#  '클로젯': {'url': '/movie/bi/mi/basic.nhn?code=181925',
#   'actors': ['하정우', '김남길', '허율']},
#  '기생충': {'url': '/movie/bi/mi/basic.nhn?code=161967',
#   'actors': ['송강호', '이선균', '조여정']},
#  '수퍼 소닉': {'url': '/movie/bi/mi/basic.nhn?code=172816',
#   'actors': ['짐 캐리', '제임스 마스던', '벤 슈와츠']}}

# %%
data = insert_grades(data)

# %%
data
# Out:
# {'정직한 후보': {'url': '/movie/bi/mi/basic.nhn?code=186821',
#   'actors': ['라미란', '김무열', '나문희'],
#   '관람객평점': 9.11,
#   '평론가평점': 5.38,
#   '네티즌평점': 7.96},
#  '작은 아씨들': {'url': '/movie/bi/mi/basic.nhn?code=186613',
#   'actors': ['시얼샤 로넌', '엠마 왓슨', '플로렌스 퓨'],
#   '관람객평점': 9.459999999999999,
#   '평론가평점': 8.0,
#   '네티즌평점': 8.98},
#  '클로젯': {'url': '/movie/bi/mi/basic.nhn?code=181925',
#   'actors': ['하정우', '김남길', '허율'],
#   '관람객평점': 8.61,
#   '평론가평점': 5.5,
#   '네티즌평점': 6.98},
#  '기생충': {'url': '/movie/bi/mi/basic.nhn?code=161967',
#   'actors': ['송강호', '이선균', '조여정'],
#   '관람객평점': 9.07,
#   '평론가평점': 9.06,
#   '네티즌평점': 8.49},
#  '수퍼 소닉': {'url': '/movie/bi/mi/basic.nhn?code=172816',
#   'actors': ['짐 캐리', '제임스 마스던', '벤 슈와츠'],
#   '관람객평점': 8.66,
#   '평론가평점': 5.0,
#   '네티즌평점': 8.370000000000001}}

# %%
data = insert_reviews(data, 20)
# Out:
# 10
# 김다솜(kmjd****)
# 너무 재밌었어용ㅠ 라미란 짱멋…
# 10
# 벚꽃의계절(twic****)
# 역시 라미란 코미디 연기는 진리다 ㅋㅋㅋㅋ
# 10
# 엥 댓글 알바라고 하먄서 평점 ㅈㄴ 낮춰놓는 게 더 댓글 알바같음 ;; 노잼 조폭 알탕 영화들보다 훨~~씬 나음 라미란 배우님 나문희 배우님 김무열 배우님 윤경호 배우님 외 많은 배우님들 ㅇ코믹 연기 넘 조와요 ㅈㄴ...
# 9
# 옹잉앙웅(t21g****)
# 개그 코드가 딱 내 스타일이야ㅋㅋ
# 6
# lililli(wken****)
# 솔직히 그렇게 엄청 웃긴지는 모르겠어요
# 10
# 공주(prin****)
# 아니 사람들마다 좋아하는 요소가 다르고 생각하는게 다른데 왜 자기랑 다르면 다 댓글알바라하는거지?; 일반화 오지네
# 9
# 샤샤샷(pnxq****)
# 기대없이 봐서 그런가 너무 웃음-_-ㅋㅋ
# 10
# 아니진짜 개재밌음 ㅠㅠ 개웃김 미쳤음 ㅋㅋㅋ역대급 코미디임ㅋㅋㅋ 진짜 한 1년동안 재밌는 영화를 못봤는데 ㄹㅇ 개꿀잼 와... 사실 극한직업도 그렇게 웃기진 않다고 생각했는데 진짜 이 영화 스토리도 그렇고 연기도 그...
# 9
# 양다리(atdx****)
# 코미디영화인데 뭔가 코미디영화같기도하고 가족영화 같기도하고 재밌더라 ㅋ
# 10
# 김고은(safi****)
# 오락영화로 즐기기엔 손색없다
# 10
# 영(seyo****)
# 예고편보고도 웃겼는데ㅋㅋㅋ풀로보니까 더웃김ㅋㅋㅋㅋ 반차라서 조조로 봤는데 웃음소리가 마스크 뚫고 나감ㅋㅋㅋ
# 4
# 김호민(ooho****)
# 음... 내가 생각하는 재미랑 여기 사람들이 재밌다고 말하는 재미랑 다른건가..??
# 10
# 잇츠미나현(sue7****)
# 초반 부터 재밌고 유쾌 했습니다 ~ ㅎㅎㅎ 라미란 연기가 하드캐리
# 1
# oen88(e2ro****)
# 대체 어떤부분이 웃낀거야 ??
# 5
# 솔직히 말할게요. 보고 왔는데 별로인 영화에요. 많이 오글거리기도 하고 전형적인 어설픈 코미디 한국영화의 클리셰가 다 들어가있네요.  저도 유튜브랑 여기 평점들 읽고 꽤 기대하면서, 그래도 괜찮은 영화겠지 했는데. ...
# 10
# interest(park****)
# 너무 너무 재밌었습니다!!
# 10
# 얍스(naye****)
# ㅋㅋ시사회로 먼저 봤는데 진짜 웃김ㅋㅋㅋ 오늘 또 봐야지! 라미란을 국회로 ㅋㅋㅋ
# 10
# 봉봉이(stil****)
# 쉴틈없이 웃었다!! 라미란언니 사랑해요!!!
# 5
# 기다리다번개처럼(ange****)
# 너무 기대를 많이 했나. 생각보다는 별로.... 스토리가 아쉽고, 뒤로 갈수록 억지웃음과 신파때문에... 표현하고자하는건 알겠으나 라미란씨를 주연으로 썼으면서 좀 아쉽습니다.
# 2
# 위버멘쉬(prof****)
# 영화의 전체적인 취지와 전개는 이해하지만 너무 엉성한 구조와 표현력이 아쉬웠던 졸작^^;
# 10
# 문덕현(mdh0****)
# 재밌다고 느끼면 추천을 아니다 비추천
# 8
# 10(loli****)
# 철없는 막내로만 재현되어왔던 에이미 캐릭터의 재발견. 어쩌면 자매 중에서 제일 고민이 많고 영리했을 여성으로.
# 10
# 이쁘구나(ehsk****)
# 왜 여성은 사랑을 해야하냐며 말하면서도 사랑을 받고 싶다고 외치던 장면이 너무나 울컥했다 ㅜ 조 꽃길만 걷길~
# 10
# 김도아(1204****)
# “자매를 미워하기엔 인생이 너무 짧아.“ 라는 명대사가 내 마음 속에 강하게 들어왔다.
# 10
# anh(abri****)
# 영화를 보고 나니 조를 응원하는 내 자신을 발견했다. 잔잔한 감동과 재미가 있는 영화.
# 9
# 재이(oran****)
# '우리의 어린시절이 끝이났다니 믿겨지지 않아.'격렬하고도 잔잔한 따뜻했던 가족이야기.
# 10
# 파야(paya****)
# 조가 여자의 전부가 사랑이라는 말이 지긋지긋하지만 너무 외롭다는 말이 공감이 간다. 무기력해지는 자신을 보며 슬퍼하는 걸 보니,나를 보는것 같아 더 슬펐다.
# 8
# ebbo0(kii1****)
# 내가 영화를 사랑하는 이유
# 10
# 13살 때 1995년도판 <작은 아씨들>을 보고 에이미를 네 자매 중 가장 미워했다. 에이미는 욕심많고 허영기 가득한 인물로 보였기 때문이다. 그런데 시간이 흘러 새로 각색한 <작은 아씨들>을 ...
# 8
# 제니(may6****)
# 그냥 티모씨 나올 때마다 심장 부여잡고 봤다.. 나만 마지막 에이미 빡쳐...?
# 10
# 놀란(son7****)
# 화려한 의상과 경이로운 스토리, 거기에 더해진 훌륭한 연기로 아름다운 영화를 조각했다.
# 10
# 김문석(eorf****)
# 엠마왓슨 진짜 존예.. 영화 너무 사랑스럽고 이뻐요..,
# 10
# 드드둠(bayl****)
# 잔잔하지만 깊은 호수같은 영화
# 10
# 아진(jane****)
# 한 장면, 장면마다 가슴 벅찰 정도로 행복감을 주는 영화.보는 내내 웃고 울었다.
# 10
# 오키드(purp****)
# 조를 보는 내내 응원했다. 조의 마지막 선택이 아쉽다.
# 10
# cottoncandypeony(jiy0****)
# 영화보다가 나도 모르게 계속 눈물이 나더라.조에 입혀진 나를 만나고, 아직 갈팡질팡한 나에게 조는 말해주는 것 같았어요
# 10
# 하린(thee****)
# 조역할을 한 배우님 연가 되게 잘하시더라
# 8
# rocker(nail****)
# 시간의 재배치로 고전을 새롭게 만든 그레타 거윅의 마술. 뛰어난 감독이 손을 대니 고전이 더욱 빛을 내는구나
# 10
# 키엘(qjwq****)
# 다들 왜이리 연기를 잘하는건가요..
# 10
# 선자(btid****)
# 시얼샤로넌 연기 미쳤… 진짜 짱짱
# 10
# 깜땀(qw13****)
# 김남길 미치게 섹시하다 진심
# 10
# gilbest(sjca****)
# 김남길 배우 연기천재 인증. 몰입력 흡입력 ㅎㄷㄷ함. 미모열일로 지루할 틈도 없음. 오컬트 무비 못보는데도 감동도 있어서 코로나 뚫고 요즘 젤 볼만한 가치가 있는 영화임.
# 10
# 지민(asdf****)
# 하정우 김남길 최고의 조합
# 10
# nobl****
# 일단 도입부 부터 온몸에소름...그 기담에서 귀신맡으신분이 무당으로 나오시는대진짜 집중하게하고 시작하네요
# 1
# KCJ0212(lahe****)
# 솔직한 평점은5.5점 정도?이 영화를 보면서 느낀건 평점알바가 정말 대단하다는것뿐이 영화가 9점대인건 너무나 큰 사기이기 때문에 1점드립다
# 9
# Hjng(alst****)
# 퇴마사 김남길 얼굴만으로 공포극복 가능. 공포영화에서조차 빛나는 눈빛연기 장인.
# 9
# 메딕(asqz****)
# 재밌으면 추천 재미없으면 비추천
# 10
# 황매력(hys8****)
# 거꾸로 거슬러 오르는 연어들처럼 신선했습니다. 코로나 이길 수 있겠는데요?
# 10
# 미스터리 처돌이로 이런 장르 정말 많이 나왔으면 좋겠는데 하필 코로나때 나왔네요ㅠㅠ긴장감 있게 잘봤습니다 확실히 또 다른 느낌의 영화였어요 단순히 장르적으로 국한되지 않는!! 배우들 다들 연기 잘하시고 다들 한번씩 ...
# 10
# 클로버(ej2r****)
# 배우들 연기보는 맛나고, 긴장감에 두손을 꼭 쥐게 되는 영화
# 10
# 행(your****)
# 진짜 미친존재감은 아역배우들..진정한 씬스틸러임 ㅠ
# 10
# 단순한 공포만 보여주는 영화가 아니라 공포 속에서 감동적인 스토리를 전개해서 교훈까지 준다는 게 인상 깊었어요 공포영화 잘 못보는데 클로젯 몇번이나 봅니다 ㅠㅠ 또한 김남길 하정우 두 배우님의 연기와 아역배우들의 연...
# 2
# 날고싶어(ljm8****)
# 초반 10분이 전부인 영화. 실망감만 가득. 무섭지도 재밌지도 않았다.
# 10
# 2023032(yjpa****)
# 하정우 김남길 캐스팅ㅠㅠ넘 좋았고 너무 재밌었음...그냥 공포 영화가 아니라 메시지도 있고 이런 영화는 오랜만인듯!
# 10
# 삡(jiny****)
# 김남길 눈빛이 다했다..재밌어요
# 10
# maimai(enma****)
# 진짜 심장 쫄깃하고 무서움 ㄷㄷㄷ 이건 극장에서 봐야함
# 10
# 난꽃이다(play****)
# 무서운거 진짜 못보는대 혼자 봤거든요 걱정하시는분들 그걸 감안하고라도 보시는거 추천드려요 정말 볼만합니다!!
# 10
# 곰수니(goms****)
# 하정우 김남길 케미 생각보다 좋고 생각보다 무서웠음 ㄷㄷㄷ
# 10
# SungBin(moon****)
# 지금 나온 영화중에는 제일 괜찮은거같아요
# 10
# 명태(xotn****)
# 클로젯이 재밌으면 추천 히트맨이 재밌으면 비추천
# 10
# brilliant_AKA_밝음(bril****)
# 비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구
# 10
# 김희정(priv****)
# 최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데..
# 10
# 리오(papi****)
# 지하철이라는 단어가 언급되는 순간, 대다수의 관객은 자신이 어디에 이입할 지를 안다.
# 10
# 멍뭉이(sumi****)
# 전 가정부가 집 벨 누를 때 부터 이 영화는 장르가 바뀐다... 역대급 꿀잼영화
# 10
# 여행의 발견(riod****)
# 황금종려상 수상작을 자막 없이 볼 수 있다는 것 자체로 좋다.
# 9
# 페르(sa02****)
# 반지하가 제일 아래인줄 알았다. 내려가보니 지하도 있었다.
# 8
# 크렙하스(powe****)
# 뭔가 모를 불쾌한 영화였다. 영화가 불쾌하다는게 아니라 보는 내내 가슴에 뭔가 영화에서 나오는 수석이 얹혀져있는 영화다.
# 10
# 도미(dudd****)
# 누군가의 냄새를 맡고, 평가하고, 묘사할 수 있는 것 또한 권력. 냄새로 서로를 알아보고 경계하고 구분짓는 동물들의 세계와 우리 사회는 참 닮아있다.
# 10
# 구마(gym9****)
# 박서준이 잘못했네ㅋㅋㅋㅋ
# 8
# 블루이즈(cank****)
# 나 또한 누군가의 사람 사는 냄새에 얼굴 찌푸리진 않았었나..
# 8
# 코튼(spee****)
# 등급조정이 필요해보입니다. 청소년들은 감당하기 버거운 내용이에요.
# 10
# 도토리라떼(ysy0****)
# 봉테일이 간과한 것 - 납골당은 눈높이에 있는 곳이 가장 비쌉니다. 죽음에도 빈부격차가 있어요.
# 10
# lsy7****
# 막판에 나오는 기우의 바램은 이루어지지 않겠지.. 계획하면 계획대로 안되니까
# 10
# 누군가는 쏟아져 내리는 빗물을 장난감 텐트로도 막을 수 있지만 다른 누군가에게는 똥구정물이 되어 차오른다. ‘계획’만으로는 올라갈 수 없는 우리네 사회구조의 냉혹하고도 잔인한 현실이 세련된 연출력으로 수석처럼 무겁게...
# 10
# hima****
# 갑에게 감사하며 을들끼리 싸웁니다. 우리사회의 축소판
# 10
# 이현우AE(hyun****)
# 사이다를 기대했는데 소주 세 잔을 얻어마신 기분이다. 첫번째 잔은 즐겁고, 두번째 잔은 어지럽고, 세번째 잔은 너무 쓰네..
# 10
# 박사장은 기택의 냄새에 대해서는 언급하지만 기우와 기정과의 냄새에 대해 언급하지 않는다. 기우와 기정은 명문 교육을 받은 자기와 같은 선상에 설 수 있는 사람이라고 인식했고 기택은 하등한 사람이라고 인식했기때문에.....
# 9
# Kwooni(kto8****)
# 인디언 추장 모자쓴 송강호의 표정이 이영화 모두를 담아낸다
# 10
# 펭귄마이크(cys4****)
# 변기위에서 담배피는 장면이 되게 강렬했음
# 10
# 에이레이(gjwl****)
# 연기는 말이 필요없고 시나리오가 너무 독특하다. 가족희비극이라고 해서 신파가 조금이라도 있을거라고 생각했는데 아니었다. 애들 데리고 보는 건 추천하지 않는다.
# 9
# STARK(lshc****)
# 소닉 성형이 신의 한수... 제작진이 성형시키기 전엔 진짜 말그대로 파란색 고슴도치였습니다 현실감 부여한답시고 라이온킹처럼 동물의 왕국 만들뻔
# 8
# 그럭저럭 재밌긴 한데 조금 유치함, 7점 주려고 했는데 에그맨을 연상시키는 짐캐리의 싱크가 대단했고 짐캐리의 슬랩스틱을 볼 수 있어서 좋았으므로 8점. 소닉 게임 영상 나올때 어릴적 소닉 한번씩 해본 사람들은 느끼는...
# 8
# 스포일러가 포함된 감상평입니다. 감상평 보기
#
#
#
#
# 																로보트닉의 성격이 상당히 평면적인 건 어쩔수없음. 중간에 외발 로봇을 왜 소닉이 아니라 토마스가 처치해야 했는지도 의문이고. 근데 소닉뽕 하나는 정말 잘채워줬다. 그린힐존도 예뻤고
# 10
# 태한추성이(lswq****)
# 소닉이 성형수술하지 않았으면 위 영화도 폭망할 뻔 했다. 개봉을 연기한 덕분에 소닉 얼굴도 냥복동에서 원작에 가깝게 성형했다. 그래서 독자들의 비판을 겸허히 받아들인 덕분이다.
# 10
# zinzin(high****)
# 세상 초딩때 맨날 씨디 가지고 게임하던 애를 영화로 보니 감회가....소닉 일단 너무 귀엽고 특히 베이비 소닉 너무 귀엽고 짐캐리는 진짜 댄스로 하드캐리함 ㅋㅋㅋ
# 10
# 냥냥(gusg****)
# 진짜 우리의 소닉,, 동년배들은 이거 안보면 90년생 아님ㅠ 소닉 세계관과 스토리를 부담스럽지 않게 풀어나가는게 아주 찐입니다! 꼭보세요!!!
# 8
# 코주부육포(ffsa****)
# 소닉 그래픽 작업 다시 안 했으면 큰일날뻔
# 8
# 푸돌이Tv(youc****)
# 뭔가 데드풀 감성이 들어있어서 재밌었고,퀵실버 감성도 들었고,분질 감성도 들어있어서 재밌었고,액션도 정말 최고였지만 비록 어린이라는 틀에 벗어나지 못한영화
# 10
# 김도원(doku****)
# 고슴도치 주제에 귀여워..
# 10
# 으악새33(wnsd****)
# 진짜 소닉 좋아하는 사람은 꼭 보는 걸 추천합니다 영화도 생각보다 잘 만들었고 에그맨 연기하는 짐캐리도 진짜 재미있게 봤어요 그리고 마지막에 꼭 시청하는 걸 추천합니다 그녀석이 있거든요 ㅎㅎ
# 8
# Sonic(qkrt****)
# 스토리는 외계인과 인간의 우정이라는 좀 고리타분한 소재인데, 게임과는 다른 캐릭터 재해석이 매력적인 작품입니다. 소닉의 스피드 연출도 상당했구요.
# 10
# 생각중(djwl****)
# 이장도면 재밋다고 생각합니다 마블시리즈마냥 시리즈도좀 나왔으면 재밋을거 같네요
# 10
# 싯대(smar****)
# 겁나재밌음 꼭봐야된다
# 10
# 영등포CGV에서 4DX로 보고 왔는데요.진짜 이 영화는 4D로 보셔야 합니다~!! 소닉 캐릭터도 인형이 움직이는것같아서 영화 내 표현처럼 '세젤귀' 임 특히 코가 강아지코같고 털이 보드라운게 느껴져서 ...
# 10
# 네더렉 박사(jjm8****)
# 개쩜 꼭 보삼 안보면 손해
# 10
# 쭌군맘(gs04****)
# 아이가 너무 재밌다고 합니다~~~관람하면 나눠주는 카드도 별거아니어도 아이들한테는 굉장한 선물인가봐요 ~~~~
# 9
# 액션씬은 노린건지는 모르겠지만 엑스맨의 그 친구가 떠오르더라구요..; 이부분이 좀 아쉬움.. 그리구 생각했던 소닉, 로버트닉 성격이랑 좀 다른데 연기를 너무 잘해서 이상하다기 보단 색다른 느낌?이라 좋았고... 어....
# 9
# jmyi****
# 아이들이랑 볼만 합니다속편 나올 것 같네요
# 10
# 두부(jueu****)
# 너무 귀엽다 ㅎㅎㅎㅎ 영화보고 나니 추억의 소닉 게임도 하고싶다
# 10
# Libra_26(enqk****)
# 제목 좀 별로긴 한데 그래도 여론 반영해서 디자인 선녀같이 뽑은건 잘했지~ 짐캐리 에그맨 연기도 기대됨 ㄹㅇ ㅋㅋ  좋다 ㅋㅋㅋ 보러간다 ㅋㅋㅋㅋ

# %%
data
# Out:
# {'정직한 후보': {'url': '/movie/bi/mi/basic.nhn?code=186821',
#   'actors': ['라미란', '김무열', '나문희'],
#   '관람객평점': 9.11,
#   '평론가평점': 5.38,
#   '네티즌평점': 7.96,
#   '리뷰': [{'평점': '10', '닉네임': '김다솜(kmjd****)', '리뷰 본문': '너무 재밌었어용ㅠ 라미란 짱멋…'},
#    {'평점': '10', '닉네임': '벚꽃의계절(twic****)', '리뷰 본문': '역시 라미란 코미디 연기는 진리다 ㅋㅋㅋㅋ'},
#    {'평점': '10',
#     '리뷰 본문': '엥 댓글 알바라고 하먄서 평점 ㅈㄴ 낮춰놓는 게 더 댓글 알바같음 ;; 노잼 조폭 알탕 영화들보다 훨~~씬 나음 라미란 배우님 나문희 배우님 김무열 배우님 윤경호 배우님 외 많은 배우님들 ㅇ코믹 연기 넘 조와요 ㅈㄴ...'},
#    {'평점': '9', '닉네임': '옹잉앙웅(t21g****)', '리뷰 본문': '개그 코드가 딱 내 스타일이야ㅋㅋ'},
#    {'평점': '6', '닉네임': 'lililli(wken****)', '리뷰 본문': '솔직히 그렇게 엄청 웃긴지는 모르겠어요'},
#    {'평점': '10',
#     '닉네임': '공주(prin****)',
#     '리뷰 본문': '아니 사람들마다 좋아하는 요소가 다르고 생각하는게 다른데 왜 자기랑 다르면 다 댓글알바라하는거지?; 일반화 오지네'},
#    {'평점': '9', '닉네임': '샤샤샷(pnxq****)', '리뷰 본문': '기대없이 봐서 그런가 너무 웃음-_-ㅋㅋ'},
#    {'평점': '10',
#     '리뷰 본문': '아니진짜 개재밌음 ㅠㅠ 개웃김 미쳤음 ㅋㅋㅋ역대급 코미디임ㅋㅋㅋ 진짜 한 1년동안 재밌는 영화를 못봤는데 ㄹㅇ 개꿀잼 와... 사실 극한직업도 그렇게 웃기진 않다고 생각했는데 진짜 이 영화 스토리도 그렇고 연기도 그...'},
#    {'평점': '9',
#     '닉네임': '양다리(atdx****)',
#     '리뷰 본문': '코미디영화인데 뭔가 코미디영화같기도하고 가족영화 같기도하고 재밌더라 ㅋ'},
#    {'평점': '10', '닉네임': '김고은(safi****)', '리뷰 본문': '오락영화로 즐기기엔 손색없다'},
#    {'평점': '10',
#     '닉네임': '영(seyo****)',
#     '리뷰 본문': '예고편보고도 웃겼는데ㅋㅋㅋ풀로보니까 더웃김ㅋㅋㅋㅋ 반차라서 조조로 봤는데 웃음소리가 마스크 뚫고 나감ㅋㅋㅋ'},
#    {'평점': '4',
#     '닉네임': '김호민(ooho****)',
#     '리뷰 본문': '음... 내가 생각하는 재미랑 여기 사람들이 재밌다고 말하는 재미랑 다른건가..??'},
#    {'평점': '10',
#     '닉네임': '잇츠미나현(sue7****)',
#     '리뷰 본문': '초반 부터 재밌고 유쾌 했습니다 ~ ㅎㅎㅎ 라미란 연기가 하드캐리'},
#    {'평점': '1', '닉네임': 'oen88(e2ro****)', '리뷰 본문': '대체 어떤부분이 웃낀거야 ??'},
#    {'평점': '5',
#     '리뷰 본문': '솔직히 말할게요. 보고 왔는데 별로인 영화에요. 많이 오글거리기도 하고 전형적인 어설픈 코미디 한국영화의 클리셰가 다 들어가있네요.  저도 유튜브랑 여기 평점들 읽고 꽤 기대하면서, 그래도 괜찮은 영화겠지 했는데. ...'},
#    {'평점': '10', '닉네임': 'interest(park****)', '리뷰 본문': '너무 너무 재밌었습니다!!'},
#    {'평점': '10',
#     '닉네임': '얍스(naye****)',
#     '리뷰 본문': 'ㅋㅋ시사회로 먼저 봤는데 진짜 웃김ㅋㅋㅋ 오늘 또 봐야지! 라미란을 국회로 ㅋㅋㅋ'},
#    {'평점': '10', '닉네임': '봉봉이(stil****)', '리뷰 본문': '쉴틈없이 웃었다!! 라미란언니 사랑해요!!!'},
#    {'평점': '5',
#     '닉네임': '기다리다번개처럼(ange****)',
#     '리뷰 본문': '너무 기대를 많이 했나. 생각보다는 별로.... 스토리가 아쉽고, 뒤로 갈수록 억지웃음과 신파때문에... 표현하고자하는건 알겠으나 라미란씨를 주연으로 썼으면서 좀 아쉽습니다.'},
#    {'평점': '2',
#     '닉네임': '위버멘쉬(prof****)',
#     '리뷰 본문': '영화의 전체적인 취지와 전개는 이해하지만 너무 엉성한 구조와 표현력이 아쉬웠던 졸작^^;'}]},
#  '작은 아씨들': {'url': '/movie/bi/mi/basic.nhn?code=186613',
#   'actors': ['시얼샤 로넌', '엠마 왓슨', '플로렌스 퓨'],
#   '관람객평점': 9.459999999999999,
#   '평론가평점': 8.0,
#   '네티즌평점': 8.98,
#   '리뷰': [{'평점': '10', '닉네임': '문덕현(mdh0****)', '리뷰 본문': '재밌다고 느끼면 추천을 아니다 비추천'},
#    {'평점': '8',
#     '닉네임': '10(loli****)',
#     '리뷰 본문': '철없는 막내로만 재현되어왔던 에이미 캐릭터의 재발견. 어쩌면 자매 중에서 제일 고민이 많고 영리했을 여성으로.'},
#    {'평점': '10',
#     '닉네임': '이쁘구나(ehsk****)',
#     '리뷰 본문': '왜 여성은 사랑을 해야하냐며 말하면서도 사랑을 받고 싶다고 외치던 장면이 너무나 울컥했다 ㅜ 조 꽃길만 걷길~'},
#    {'평점': '10',
#     '닉네임': '김도아(1204****)',
#     '리뷰 본문': '“자매를 미워하기엔 인생이 너무 짧아.“ 라는 명대사가 내 마음 속에 강하게 들어왔다.'},
#    {'평점': '10',
#     '닉네임': 'anh(abri****)',
#     '리뷰 본문': '영화를 보고 나니 조를 응원하는 내 자신을 발견했다. 잔잔한 감동과 재미가 있는 영화.'},
#    {'평점': '9',
#     '닉네임': '재이(oran****)',
#     '리뷰 본문': "'우리의 어린시절이 끝이났다니 믿겨지지 않아.'격렬하고도 잔잔한 따뜻했던 가족이야기."},
#    {'평점': '10',
#     '닉네임': '파야(paya****)',
#     '리뷰 본문': '조가 여자의 전부가 사랑이라는 말이 지긋지긋하지만 너무 외롭다는 말이 공감이 간다. 무기력해지는 자신을 보며 슬퍼하는 걸 보니,나를 보는것 같아 더 슬펐다.'},
#    {'평점': '8', '닉네임': 'ebbo0(kii1****)', '리뷰 본문': '내가 영화를 사랑하는 이유'},
#    {'평점': '10',
#     '리뷰 본문': '13살 때 1995년도판 <작은 아씨들>을 보고 에이미를 네 자매 중 가장 미워했다. 에이미는 욕심많고 허영기 가득한 인물로 보였기 때문이다. 그런데 시간이 흘러 새로 각색한 <작은 아씨들>을 ...'},
#    {'평점': '8',
#     '닉네임': '제니(may6****)',
#     '리뷰 본문': '그냥 티모씨 나올 때마다 심장 부여잡고 봤다.. 나만 마지막 에이미 빡쳐...?'},
#    {'평점': '10',
#     '닉네임': '놀란(son7****)',
#     '리뷰 본문': '화려한 의상과 경이로운 스토리, 거기에 더해진 훌륭한 연기로 아름다운 영화를 조각했다.'},
#    {'평점': '10',
#     '닉네임': '김문석(eorf****)',
#     '리뷰 본문': '엠마왓슨 진짜 존예.. 영화 너무 사랑스럽고 이뻐요..,'},
#    {'평점': '10', '닉네임': '드드둠(bayl****)', '리뷰 본문': '잔잔하지만 깊은 호수같은 영화'},
#    {'평점': '10',
#     '닉네임': '아진(jane****)',
#     '리뷰 본문': '한 장면, 장면마다 가슴 벅찰 정도로 행복감을 주는 영화.보는 내내 웃고 울었다.'},
#    {'평점': '10',
#     '닉네임': '오키드(purp****)',
#     '리뷰 본문': '조를 보는 내내 응원했다. 조의 마지막 선택이 아쉽다.'},
#    {'평점': '10',
#     '닉네임': 'cottoncandypeony(jiy0****)',
#     '리뷰 본문': '영화보다가 나도 모르게 계속 눈물이 나더라.조에 입혀진 나를 만나고, 아직 갈팡질팡한 나에게 조는 말해주는 것 같았어요'},
#    {'평점': '10', '닉네임': '하린(thee****)', '리뷰 본문': '조역할을 한 배우님 연가 되게 잘하시더라'},
#    {'평점': '8',
#     '닉네임': 'rocker(nail****)',
#     '리뷰 본문': '시간의 재배치로 고전을 새롭게 만든 그레타 거윅의 마술. 뛰어난 감독이 손을 대니 고전이 더욱 빛을 내는구나'},
#    {'평점': '10', '닉네임': '키엘(qjwq****)', '리뷰 본문': '다들 왜이리 연기를 잘하는건가요..'},
#    {'평점': '10', '닉네임': '선자(btid****)', '리뷰 본문': '시얼샤로넌 연기 미쳤… 진짜 짱짱'}]},
#  '클로젯': {'url': '/movie/bi/mi/basic.nhn?code=181925',
#   'actors': ['하정우', '김남길', '허율'],
#   '관람객평점': 8.61,
#   '평론가평점': 5.5,
#   '네티즌평점': 6.98,
#   '리뷰': [{'평점': '10', '닉네임': '깜땀(qw13****)', '리뷰 본문': '김남길 미치게 섹시하다 진심'},
#    {'평점': '10',
#     '닉네임': 'gilbest(sjca****)',
#     '리뷰 본문': '김남길 배우 연기천재 인증. 몰입력 흡입력 ㅎㄷㄷ함. 미모열일로 지루할 틈도 없음. 오컬트 무비 못보는데도 감동도 있어서 코로나 뚫고 요즘 젤 볼만한 가치가 있는 영화임.'},
#    {'평점': '10', '닉네임': '지민(asdf****)', '리뷰 본문': '하정우 김남길 최고의 조합'},
#    {'평점': '10',
#     '닉네임': 'nobl****',
#     '리뷰 본문': '일단 도입부 부터 온몸에소름...그 기담에서 귀신맡으신분이 무당으로 나오시는대진짜 집중하게하고 시작하네요'},
#    {'평점': '1',
#     '닉네임': 'KCJ0212(lahe****)',
#     '리뷰 본문': '솔직한 평점은5.5점 정도?이 영화를 보면서 느낀건 평점알바가 정말 대단하다는것뿐이 영화가 9점대인건 너무나 큰 사기이기 때문에 1점드립다'},
#    {'평점': '9',
#     '닉네임': 'Hjng(alst****)',
#     '리뷰 본문': '퇴마사 김남길 얼굴만으로 공포극복 가능. 공포영화에서조차 빛나는 눈빛연기 장인.'},
#    {'평점': '9', '닉네임': '메딕(asqz****)', '리뷰 본문': '재밌으면 추천 재미없으면 비추천'},
#    {'평점': '10',
#     '닉네임': '황매력(hys8****)',
#     '리뷰 본문': '거꾸로 거슬러 오르는 연어들처럼 신선했습니다. 코로나 이길 수 있겠는데요?'},
#    {'평점': '10',
#     '리뷰 본문': '미스터리 처돌이로 이런 장르 정말 많이 나왔으면 좋겠는데 하필 코로나때 나왔네요ㅠㅠ긴장감 있게 잘봤습니다 확실히 또 다른 느낌의 영화였어요 단순히 장르적으로 국한되지 않는!! 배우들 다들 연기 잘하시고 다들 한번씩 ...'},
#    {'평점': '10',
#     '닉네임': '클로버(ej2r****)',
#     '리뷰 본문': '배우들 연기보는 맛나고, 긴장감에 두손을 꼭 쥐게 되는 영화'},
#    {'평점': '10', '닉네임': '행(your****)', '리뷰 본문': '진짜 미친존재감은 아역배우들..진정한 씬스틸러임 ㅠ'},
#    {'평점': '10',
#     '리뷰 본문': '단순한 공포만 보여주는 영화가 아니라 공포 속에서 감동적인 스토리를 전개해서 교훈까지 준다는 게 인상 깊었어요 공포영화 잘 못보는데 클로젯 몇번이나 봅니다 ㅠㅠ 또한 김남길 하정우 두 배우님의 연기와 아역배우들의 연...'},
#    {'평점': '2',
#     '닉네임': '날고싶어(ljm8****)',
#     '리뷰 본문': '초반 10분이 전부인 영화. 실망감만 가득. 무섭지도 재밌지도 않았다.'},
#    {'평점': '10',
#     '닉네임': '2023032(yjpa****)',
#     '리뷰 본문': '하정우 김남길 캐스팅ㅠㅠ넘 좋았고 너무 재밌었음...그냥 공포 영화가 아니라 메시지도 있고 이런 영화는 오랜만인듯!'},
#    {'평점': '10', '닉네임': '삡(jiny****)', '리뷰 본문': '김남길 눈빛이 다했다..재밌어요'},
#    {'평점': '10',
#     '닉네임': 'maimai(enma****)',
#     '리뷰 본문': '진짜 심장 쫄깃하고 무서움 ㄷㄷㄷ 이건 극장에서 봐야함'},
#    {'평점': '10',
#     '닉네임': '난꽃이다(play****)',
#     '리뷰 본문': '무서운거 진짜 못보는대 혼자 봤거든요 걱정하시는분들 그걸 감안하고라도 보시는거 추천드려요 정말 볼만합니다!!'},
#    {'평점': '10',
#     '닉네임': '곰수니(goms****)',
#     '리뷰 본문': '하정우 김남길 케미 생각보다 좋고 생각보다 무서웠음 ㄷㄷㄷ'},
#    {'평점': '10', '닉네임': 'SungBin(moon****)', '리뷰 본문': '지금 나온 영화중에는 제일 괜찮은거같아요'},
#    {'평점': '10',
#     '닉네임': '명태(xotn****)',
#     '리뷰 본문': '클로젯이 재밌으면 추천 히트맨이 재밌으면 비추천'}]},
#  '기생충': {'url': '/movie/bi/mi/basic.nhn?code=161967',
#   'actors': ['송강호', '이선균', '조여정'],
#   '관람객평점': 9.07,
#   '평론가평점': 9.06,
#   '네티즌평점': 8.49,
#   '리뷰': [{'평점': '10',
#     '닉네임': 'brilliant_AKA_밝음(bril****)',
#     '리뷰 본문': '비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구'},
#    {'평점': '10',
#     '닉네임': '김희정(priv****)',
#     '리뷰 본문': '최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데..'},
#    {'평점': '10',
#     '닉네임': '리오(papi****)',
#     '리뷰 본문': '지하철이라는 단어가 언급되는 순간, 대다수의 관객은 자신이 어디에 이입할 지를 안다.'},
#    {'평점': '10',
#     '닉네임': '멍뭉이(sumi****)',
#     '리뷰 본문': '전 가정부가 집 벨 누를 때 부터 이 영화는 장르가 바뀐다... 역대급 꿀잼영화'},
#    {'평점': '10',
#     '닉네임': '여행의 발견(riod****)',
#     '리뷰 본문': '황금종려상 수상작을 자막 없이 볼 수 있다는 것 자체로 좋다.'},
#    {'평점': '9',
#     '닉네임': '페르(sa02****)',
#     '리뷰 본문': '반지하가 제일 아래인줄 알았다. 내려가보니 지하도 있었다.'},
#    {'평점': '8',
#     '닉네임': '크렙하스(powe****)',
#     '리뷰 본문': '뭔가 모를 불쾌한 영화였다. 영화가 불쾌하다는게 아니라 보는 내내 가슴에 뭔가 영화에서 나오는 수석이 얹혀져있는 영화다.'},
#    {'평점': '10',
#     '닉네임': '도미(dudd****)',
#     '리뷰 본문': '누군가의 냄새를 맡고, 평가하고, 묘사할 수 있는 것 또한 권력. 냄새로 서로를 알아보고 경계하고 구분짓는 동물들의 세계와 우리 사회는 참 닮아있다.'},
#    {'평점': '10', '닉네임': '구마(gym9****)', '리뷰 본문': '박서준이 잘못했네ㅋㅋㅋㅋ'},
#    {'평점': '8',
#     '닉네임': '블루이즈(cank****)',
#     '리뷰 본문': '나 또한 누군가의 사람 사는 냄새에 얼굴 찌푸리진 않았었나..'},
#    {'평점': '8',
#     '닉네임': '코튼(spee****)',
#     '리뷰 본문': '등급조정이 필요해보입니다. 청소년들은 감당하기 버거운 내용이에요.'},
#    {'평점': '10',
#     '닉네임': '도토리라떼(ysy0****)',
#     '리뷰 본문': '봉테일이 간과한 것 - 납골당은 눈높이에 있는 곳이 가장 비쌉니다. 죽음에도 빈부격차가 있어요.'},
#    {'평점': '10',
#     '닉네임': 'lsy7****',
#     '리뷰 본문': '막판에 나오는 기우의 바램은 이루어지지 않겠지.. 계획하면 계획대로 안되니까'},
#    {'평점': '10',
#     '리뷰 본문': '누군가는 쏟아져 내리는 빗물을 장난감 텐트로도 막을 수 있지만 다른 누군가에게는 똥구정물이 되어 차오른다. ‘계획’만으로는 올라갈 수 없는 우리네 사회구조의 냉혹하고도 잔인한 현실이 세련된 연출력으로 수석처럼 무겁게...'},
#    {'평점': '10', '닉네임': 'hima****', '리뷰 본문': '갑에게 감사하며 을들끼리 싸웁니다. 우리사회의 축소판'},
#    {'평점': '10',
#     '닉네임': '이현우AE(hyun****)',
#     '리뷰 본문': '사이다를 기대했는데 소주 세 잔을 얻어마신 기분이다. 첫번째 잔은 즐겁고, 두번째 잔은 어지럽고, 세번째 잔은 너무 쓰네..'},
#    {'평점': '10',
#     '리뷰 본문': '박사장은 기택의 냄새에 대해서는 언급하지만 기우와 기정과의 냄새에 대해 언급하지 않는다. 기우와 기정은 명문 교육을 받은 자기와 같은 선상에 설 수 있는 사람이라고 인식했고 기택은 하등한 사람이라고 인식했기때문에.....'},
#    {'평점': '9',
#     '닉네임': 'Kwooni(kto8****)',
#     '리뷰 본문': '인디언 추장 모자쓴 송강호의 표정이 이영화 모두를 담아낸다'},
#    {'평점': '10', '닉네임': '펭귄마이크(cys4****)', '리뷰 본문': '변기위에서 담배피는 장면이 되게 강렬했음'},
#    {'평점': '10',
#     '닉네임': '에이레이(gjwl****)',
#     '리뷰 본문': '연기는 말이 필요없고 시나리오가 너무 독특하다. 가족희비극이라고 해서 신파가 조금이라도 있을거라고 생각했는데 아니었다. 애들 데리고 보는 건 추천하지 않는다.'}]},
#  '수퍼 소닉': {'url': '/movie/bi/mi/basic.nhn?code=172816',
#   'actors': ['짐 캐리', '제임스 마스던', '벤 슈와츠'],
#   '관람객평점': 8.66,
#   '평론가평점': 5.0,
#   '네티즌평점': 8.370000000000001,
#   '리뷰': [{'평점': '9',
#     '닉네임': 'STARK(lshc****)',
#     '리뷰 본문': '소닉 성형이 신의 한수... 제작진이 성형시키기 전엔 진짜 말그대로 파란색 고슴도치였습니다 현실감 부여한답시고 라이온킹처럼 동물의 왕국 만들뻔'},
#    {'평점': '8',
#     '리뷰 본문': '그럭저럭 재밌긴 한데 조금 유치함, 7점 주려고 했는데 에그맨을 연상시키는 짐캐리의 싱크가 대단했고 짐캐리의 슬랩스틱을 볼 수 있어서 좋았으므로 8점. 소닉 게임 영상 나올때 어릴적 소닉 한번씩 해본 사람들은 느끼는...'},
#    {'평점': '8',
#     '리뷰 본문': '스포일러가 포함된 감상평입니다. 감상평 보기\n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t로보트닉의 성격이 상당히 평면적인 건 어쩔수없음. 중간에 외발 로봇을 왜 소닉이 아니라 토마스가 처치해야 했는지도 의문이고. 근데 소닉뽕 하나는 정말 잘채워줬다. 그린힐존도 예뻤고'},
#    {'평점': '10',
#     '닉네임': '태한추성이(lswq****)',
#     '리뷰 본문': '소닉이 성형수술하지 않았으면 위 영화도 폭망할 뻔 했다. 개봉을 연기한 덕분에 소닉 얼굴도 냥복동에서 원작에 가깝게 성형했다. 그래서 독자들의 비판을 겸허히 받아들인 덕분이다.'},
#    {'평점': '10',
#     '닉네임': 'zinzin(high****)',
#     '리뷰 본문': '세상 초딩때 맨날 씨디 가지고 게임하던 애를 영화로 보니 감회가....소닉 일단 너무 귀엽고 특히 베이비 소닉 너무 귀엽고 짐캐리는 진짜 댄스로 하드캐리함 ㅋㅋㅋ'},
#    {'평점': '10',
#     '닉네임': '냥냥(gusg****)',
#     '리뷰 본문': '진짜 우리의 소닉,, 동년배들은 이거 안보면 90년생 아님ㅠ 소닉 세계관과 스토리를 부담스럽지 않게 풀어나가는게 아주 찐입니다! 꼭보세요!!!'},
#    {'평점': '8', '닉네임': '코주부육포(ffsa****)', '리뷰 본문': '소닉 그래픽 작업 다시 안 했으면 큰일날뻔'},
#    {'평점': '8',
#     '닉네임': '푸돌이Tv(youc****)',
#     '리뷰 본문': '뭔가 데드풀 감성이 들어있어서 재밌었고,퀵실버 감성도 들었고,분질 감성도 들어있어서 재밌었고,액션도 정말 최고였지만 비록 어린이라는 틀에 벗어나지 못한영화'},
#    {'평점': '10', '닉네임': '김도원(doku****)', '리뷰 본문': '고슴도치 주제에 귀여워..'},
#    {'평점': '10',
#     '닉네임': '으악새33(wnsd****)',
#     '리뷰 본문': '진짜 소닉 좋아하는 사람은 꼭 보는 걸 추천합니다 영화도 생각보다 잘 만들었고 에그맨 연기하는 짐캐리도 진짜 재미있게 봤어요 그리고 마지막에 꼭 시청하는 걸 추천합니다 그녀석이 있거든요 ㅎㅎ'},
#    {'평점': '8',
#     '닉네임': 'Sonic(qkrt****)',
#     '리뷰 본문': '스토리는 외계인과 인간의 우정이라는 좀 고리타분한 소재인데, 게임과는 다른 캐릭터 재해석이 매력적인 작품입니다. 소닉의 스피드 연출도 상당했구요.'},
#    {'평점': '10',
#     '닉네임': '생각중(djwl****)',
#     '리뷰 본문': '이장도면 재밋다고 생각합니다 마블시리즈마냥 시리즈도좀 나왔으면 재밋을거 같네요'},
#    {'평점': '10', '닉네임': '싯대(smar****)', '리뷰 본문': '겁나재밌음 꼭봐야된다'},
#    {'평점': '10',
#     '리뷰 본문': "영등포CGV에서 4DX로 보고 왔는데요.진짜 이 영화는 4D로 보셔야 합니다~!! 소닉 캐릭터도 인형이 움직이는것같아서 영화 내 표현처럼 '세젤귀' 임 특히 코가 강아지코같고 털이 보드라운게 느껴져서 ..."},
#    {'평점': '10', '닉네임': '네더렉 박사(jjm8****)', '리뷰 본문': '개쩜 꼭 보삼 안보면 손해'},
#    {'평점': '10',
#     '닉네임': '쭌군맘(gs04****)',
#     '리뷰 본문': '아이가 너무 재밌다고 합니다~~~관람하면 나눠주는 카드도 별거아니어도 아이들한테는 굉장한 선물인가봐요 ~~~~'},
#    {'평점': '9',
#     '리뷰 본문': '액션씬은 노린건지는 모르겠지만 엑스맨의 그 친구가 떠오르더라구요..; 이부분이 좀 아쉬움.. 그리구 생각했던 소닉, 로버트닉 성격이랑 좀 다른데 연기를 너무 잘해서 이상하다기 보단 색다른 느낌?이라 좋았고... 어....'},
#    {'평점': '9', '닉네임': 'jmyi****', '리뷰 본문': '아이들이랑 볼만 합니다속편 나올 것 같네요'},
#    {'평점': '10',
#     '닉네임': '두부(jueu****)',
#     '리뷰 본문': '너무 귀엽다 ㅎㅎㅎㅎ 영화보고 나니 추억의 소닉 게임도 하고싶다'},
#    {'평점': '10',
#     '닉네임': 'Libra_26(enqk****)',
#     '리뷰 본문': '제목 좀 별로긴 한데 그래도 여론 반영해서 디자인 선녀같이 뽑은건 잘했지~ 짐캐리 에그맨 연기도 기대됨 ㄹㅇ ㅋㅋ  좋다 ㅋㅋㅋ 보러간다 ㅋㅋㅋㅋ'}]}}

# %%
dic_to_json(data, 'assignment')
